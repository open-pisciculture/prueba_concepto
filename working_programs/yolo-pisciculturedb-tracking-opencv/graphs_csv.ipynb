# %% [markdown]
# # tinyYoloV4 Processed Video Features: Graphs

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('video_data_firstTry.csv')
df["Datetime"] = pd.to_datetime(df["timestamp"])
df = df.set_index("Datetime")
del df["timestamp"]
del df["Average Distance"]
df.head()
# Out:
#                      Average X  Average Y  Average Pairwise Distance
# Datetime
# 2021-10-01 13:29:44        225        156                   180.8755
# 2021-10-01 18:46:01         22          3                    10.5255
# 2021-10-02 06:49:02        230        152                   187.9762
# 2021-10-01 11:05:13        202        127                   193.5140
# 2021-10-02 06:23:55        189        119                   176.3890

# %%
df.plot(figsize=(20,5))
